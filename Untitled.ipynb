# %%
def hello(name):
    print("Hello, {}!!".format(name))

# %%
hello("America")
# Out:
# Hello, America!!

# %%
import time
for n in range(10):
    print("待って for 5 seconds {}".format(n))
    time.sleep(5)
# Out:
# 待って for 5 seconds 0
# 待って for 5 seconds 1
# 待って for 5 seconds 2

# %% [markdown]
# # markdownの後にheadingでこんな感じに見出しがつく。

# %% [markdown]
# # 式の練習。式番号の付け方は分からん。2014の時点では実装されていない模様である。
#
# \begin{equation}
#     \gamma = e^{+}e^{-}
# \end{equation}
#
# \begin{eqnarray}
#     ma &=& F \\
#     \rho V a &=& F
# \end{eqnarray}
#  markdownモードに画像をドラッグするとあら不思議！→
#  ![hoge.PNG](attachment:hoge.PNG)
#  まぁ、Githubにあげたらこうなっちゃいますよね。
